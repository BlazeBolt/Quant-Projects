# %% [markdown]
# Calculate both a short-term (10-day) and long-term (30-day) moving average A buy signal is generated when the short-term MA crosses above the long-term MA A sell signal is generated when the short-term MA crosses below the long-term MA
